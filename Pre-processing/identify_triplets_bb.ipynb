# %%
import spacy 
from spacy.matcher import Matcher
import textacy
import pandas as pd 
import numpy as np 

nlp = spacy.load('en_core_web_sm')

from spacy.symbols import NOUN, PROPN, VERB
from spacy.tokens import Doc, Span, Token

# %%
# First let's import cnn

cnn = pd.read_csv("~/Documents/moral_templates/Data/breitbart_articles.csv")

# Drop articles for which I don't have the text 

cnn = cnn.dropna(subset=['clean_strings'])

# %%
def subject_verb_object_triples(doc):

    sents = doc.sents

    for sent in sents:
        start_i = sent[0].i

        verbs = textacy.spacier.utils.get_main_verbs_of_sent(sent)
        for verb in verbs:
            subjs = textacy.spacier.utils.get_subjects_of_verb(verb)
            if not subjs:
                continue
            objs = textacy.spacier.utils.get_objects_of_verb(verb)
            if not objs:
                continue

            # add adjacent auxiliaries to verbs, for context
            # and add compounds to compound nouns
            verb_span = textacy.spacier.utils.get_span_for_verb_auxiliaries(verb)
            verb = sent[verb_span[0] - start_i : verb_span[1] - start_i + 1]
            for subj in subjs:
                subj_dep = subj.dep_
                subj_tag = subj.tag_
                subj = sent[
                    textacy.spacier.utils.get_span_for_compound_noun(subj)[0]
                    - start_i : subj.i
                    - start_i
                    + 1
                ]
                for obj in objs:
                    if obj.pos == NOUN:
                        span = textacy.spacier.utils.get_span_for_compound_noun(obj)
                    elif obj.pos == VERB:
                        span = textacy.spacier.utils.get_span_for_verb_auxiliaries(obj)
                    else:
                        span = (obj.i, obj.i)
                    obj_dep = obj.dep_
                    obj_tag = obj.tag_
                    obj = sent[span[0] - start_i : span[1] - start_i + 1]
                    end_pos = span[1] 

                    yield (start_i,subj, subj_dep, subj_tag, verb, obj, obj_dep, obj_tag,  end_pos)

# %%
# Create a function for creating the dataframe 

def create_svo_dataframe(doc): 

    start_list = []
    subject_list = []
    sdep_list = []
    stag_list = []
    verb_list = []
    object_list = []
    odep_list = []
    otag_list = []
    end_list = []

    triplets = subject_verb_object_triples(doc)

    for triplet in triplets:
        start = triplet[0]
        subj = triplet[1]
        subj_dep = triplet[2]
        subj_tag = triplet[3]
        verb = triplet[4]
        obj = triplet[5]
        obj_dep = triplet[6]
        obj_tag = triplet[7]
        end = triplet[8]

        start_list.append(start)
        subject_list.append(subj)
        sdep_list.append(subj_dep)
        stag_list.append(subj_tag)
        verb_list.append(verb)
        object_list.append(obj)
        odep_list.append(obj_dep)
        otag_list.append(obj_tag)
        end_list.append(end)
    
    dict = {'subject': subject_list, 
        'verb': verb_list, 
        'object': object_list, 
        'start': start_list, 
        'end': end_list, 
        'subj_dep': sdep_list, 
        'subj_tag': stag_list, 
        'obj_dep': odep_list, 
        'obj_tag': otag_list}
    
    svo_df = pd.DataFrame(dict)

    return svo_df

# %%
svodf = pd.DataFrame()

for i in range(len(cnn)): 
    doc = nlp(cnn.iloc[i]['clean_strings'])
    df = create_svo_dataframe(doc)
    df['Document'] = i 
    df['publication'] = cnn.iloc[i]['publication']
    svodf = svodf.append(df, ignore_index = True)
    if (i % 100 == 0):
        print(f'working on article {i}')

svodf.tail(25)
# Out:
# working on article 0
# working on article 100
# working on article 200
# working on article 300
# working on article 400
# working on article 500
# working on article 600
# working on article 700
# working on article 800
# working on article 900
# working on article 1000
# working on article 1100
# working on article 1200
# working on article 1300
# working on article 1400
# working on article 1500
# working on article 1600
# working on article 1700
# working on article 1800
# working on article 1900
# working on article 2000
# working on article 2100
# working on article 2200
# working on article 2300
# working on article 2400
# working on article 2500
# working on article 2600
# working on article 2700
# working on article 2800
# working on article 2900
# working on article 3000
# working on article 3100
# working on article 3200
# working on article 3300
# working on article 3400
# working on article 3500
# working on article 3600
# working on article 3700
# working on article 3800
# working on article 3900
# working on article 4000
# working on article 4100
# working on article 4200
# working on article 4300
# working on article 4400
# working on article 4500
# working on article 4600
# working on article 4700
# working on article 4800
# working on article 4900
# working on article 5000
# working on article 5100
# working on article 5200
# working on article 5300
# working on article 5400
# working on article 5500
# working on article 5600
# working on article 5700
# working on article 5800
# working on article 5900
# working on article 6000
# working on article 6100
# working on article 6200
# working on article 6300
# working on article 6400
# working on article 6500
# working on article 6600
# working on article 6700
# working on article 6800
# working on article 6900
# working on article 7000
# working on article 7100
# working on article 7200
# working on article 7300
# working on article 7400
# working on article 7500
# working on article 7600
# working on article 7700
# working on article 7800
# working on article 7900
# working on article 8000
# working on article 8100
# working on article 8200
# working on article 8300
# working on article 8400
# working on article 8500
# working on article 8600
# working on article 8700
# working on article 8800
# working on article 8900
# working on article 9000
# working on article 9100
# working on article 9200
# working on article 9300
# working on article 9400
# working on article 9500
# working on article 9600
# working on article 9700
# working on article 9800
# working on article 9900
# working on article 10000
# working on article 10100
# working on article 10200
# working on article 10300
# working on article 10400
# working on article 10500
# working on article 10600
# working on article 10700
# working on article 10800
# working on article 10900
# working on article 11000
# working on article 11100
# working on article 11200
# working on article 11300
# working on article 11400
# working on article 11500
# working on article 11600
# working on article 11700
# working on article 11800
# working on article 11900
# working on article 12000
# working on article 12100
# working on article 12200
# working on article 12300
# working on article 12400
# working on article 12500
# working on article 12600
# working on article 12700
# working on article 12800
# working on article 12900
# working on article 13000
# working on article 13100
# working on article 13200
# working on article 13300
# working on article 13400
# working on article 13500
# working on article 13600
# working on article 13700
# working on article 13800
# working on article 13900
# working on article 14000
# working on article 14100
# working on article 14200
# working on article 14300
# working on article 14400
# working on article 14500
# working on article 14600
# working on article 14700
# working on article 14800
# working on article 14900
# working on article 15000
# working on article 15100
# working on article 15200
# working on article 15300
# working on article 15400
# working on article 15500
# working on article 15600
# working on article 15700
# working on article 15800
# working on article 15900
# working on article 16000
# working on article 16100
# working on article 16200
# working on article 16300
# working on article 16400
# working on article 16500
# working on article 16600
# working on article 16700
# working on article 16800
# working on article 16900
# working on article 17000
# working on article 17100
# working on article 17200
# working on article 17300
# working on article 17400
# working on article 17500
# working on article 17600
# working on article 17700
# working on article 17800
# working on article 17900
# working on article 18000
# working on article 18100
# working on article 18200
# working on article 18300
# working on article 18400
# working on article 18500
# working on article 18600
# working on article 18700
# working on article 18800
# working on article 18900
# working on article 19000
# working on article 19100
# working on article 19200
# working on article 19300
# working on article 19400
# working on article 19500
# working on article 19600
# working on article 19700
# working on article 19800
# working on article 19900
# working on article 20000
# working on article 20100
# working on article 20200
# working on article 20300
# working on article 20400
# working on article 20500
# working on article 20600
# working on article 20700
# working on article 20800
# working on article 20900
# working on article 21000
# working on article 21100
# working on article 21200
# working on article 21300
# working on article 21400
# working on article 21500
# working on article 21600
# working on article 21700
# working on article 21800
# working on article 21900
# working on article 22000
# working on article 22100
# working on article 22200
# working on article 22300
# working on article 22400
# working on article 22500
# working on article 22600
# working on article 22700
# working on article 22800
# working on article 22900
# working on article 23000
# working on article 23100
# working on article 23200
# working on article 23300
# working on article 23400
# working on article 23500
# working on article 23600
# working on article 23700
#                  subject                  verb                    object  \
# 481592         (Clinton)      (would, appoint)                 (liberal)
# 481593         (Clinton)  (would, never, make)                  (policy)
# 481594          (person)         (could, side)     (immigration, policy)
# 481595        (justices)          (to, strike)                   (parts)
# 481596           (Trump)          (to, create)                  (policy)
# 481597          (lawyer)              (proves)                 (himself)
# 481598          (lawyer)              (proves)                      (be)
# 481599          (nation)     (has, threatened)               (to, flood)
# 481600       (president)     (has, threatened)               (to, flood)
# 481601             (all)            (approved)                    (vote)
# 481602             (who)                (feed)                (refugees)
# 481603             (You)      (have, betrayed)                (promises)
# 481604        (Brussels)              (agreed)             (to, provide)
# 481605    (Mr., Erdoğan)             (stopped)                (crossing)
# 481606     (governments)              (follow)              (parliament)
# 481607      (commission)              (follow)              (parliament)
# 481608           (terms)      (will, be, seen)  (to, have, been, broken)
# 481609  (EU, Parliament)     (was, discussing)                  (motion)
# 481610          (Turkey)      (did, not, need)                (to, join)
# 481611              (he)            (employed)                (rhetoric)
# 481612    (Mr., Erdoğan)            (promised)                    (open)
# 481613          (Turkey)                (made)                 (demands)
# 481614          (Turkey)                (made)                  (access)
# 481615          (Turkey)                (made)                (citizens)
# 481616          (Turkey)                (made)             (accelerated)
#
#          start     end   subj_dep subj_tag obj_dep obj_tag  Document  \
# 481592  1882.0  1886.0      nsubj      NNP    dobj      NN     23779
# 481593  1882.0  1914.0      nsubj      NNP    dobj      NN     23779
# 481594  1986.0  2014.0      nsubj       NN    dobj      NN     23779
# 481595  1986.0  2008.0      nsubj      NNS    dobj     NNS     23779
# 481596  2016.0  2037.0      nsubj       JJ    dobj      NN     23779
# 481597  2050.0  2061.0      nsubj       NN    dobj     PRP     23779
# 481598  2050.0  2063.0      nsubj       NN   xcomp      VB     23779
# 481599     0.0    30.0      nsubj       NN   xcomp      VB     23780
# 481600     0.0    30.0      nsubj       NN   xcomp      VB     23780
# 481601    74.0    88.0      nsubj       DT    dobj      NN     23780
# 481602    92.0   102.0      nsubj       WP    dobj     NNS     23780
# 481603   116.0   121.0      nsubj      PRP    dobj     NNS     23780
# 481604   131.0   140.0      nsubj      NNP   xcomp      VB     23780
# 481605   131.0   174.0      nsubj      NNP    dobj     VBG     23780
# 481606   280.0   288.0      nsubj      NNS    dobj      NN     23780
# 481607   280.0   288.0       conj       NN    dobj      NN     23780
# 481608   280.0   302.0  nsubjpass      NNS   xcomp     VBN     23780
# 481609   306.0   316.0      nsubj      NNP    dobj      NN     23780
# 481610   306.0   329.0      nsubj      NNP   xcomp      VB     23780
# 481611   352.0   380.0      nsubj      PRP    dobj      NN     23780
# 481612   383.0   394.0      nsubj      NNP   xcomp      VB     23780
# 481613   432.0   441.0      nsubj      NNP    dobj     NNS     23780
# 481614   432.0   454.0      nsubj      NNP    conj      NN     23780
# 481615   432.0   463.0      nsubj      NNP    conj     NNS     23780
# 481616   432.0   466.0      nsubj      NNP    conj      JJ     23780
#
#        publication
# 481592   Breitbart
# 481593   Breitbart
# 481594   Breitbart
# 481595   Breitbart
# 481596   Breitbart
# 481597   Breitbart
# 481598   Breitbart
# 481599   Breitbart
# 481600   Breitbart
# 481601   Breitbart
# 481602   Breitbart
# 481603   Breitbart
# 481604   Breitbart
# 481605   Breitbart
# 481606   Breitbart
# 481607   Breitbart
# 481608   Breitbart
# 481609   Breitbart
# 481610   Breitbart
# 481611   Breitbart
# 481612   Breitbart
# 481613   Breitbart
# 481614   Breitbart
# 481615   Breitbart
# 481616   Breitbart

# %%
svodf_filtered = svodf[(svodf.obj_dep=='dobj')]
svodf_final = svodf_filtered[svodf_filtered.obj_tag.isin(["NN", "NNS", "NNP", "NNPS"])]


svodf_final.tail(50)
# Out:
#                            subject                    verb  \
# 481541                 (provision)                 (gives)
# 481542                       (who)                (enters)
# 481544                     (Court)                (quoted)
# 481545                     (Court)        (has, sustained)
# 481546                     (Trump)                (impose)
# 481550                   (statute)               (conveys)
# 481551                 (president)             (to, enact)
# 481552                   (statute)   (does, not, delegate)
# 481553                  (Congress)          (could, amend)
# 481554                    (voters)         (can, consider)
# 481555                       (who)        (have, violated)
# 481556                  (senators)               (opposed)
# 481558                        (he)               (follows)
# 481559          (immigration, law)                 (takes)
# 481560                (foreigners)               (request)
# 481562                (government)   (can, not, ascertain)
# 481564  (immigration, authorities)       (must, establish)
# 481565                       (law)              (requires)
# 481567                     (state)               (deprive)
# 481568      (Due, Process, Clause)              (includes)
# 481571                    (Judges)         (Would, Uphold)
# 481572          (Fifth, Amendment)  (does, not, constrain)
# 481573                       (who)            (can, enter)
# 481574               (politicians)            (could, ban)
# 481575                     (court)               (reviews)
# 481576                       (who)                   (fit)
# 481577                   (inquiry)    (would, precipitate)
# 481578                       (ban)             (satisfies)
# 481579                    (policy)               (defines)
# 481580                (government)               (defines)
# 481581                  (Congress)          (must, choose)
# 481582              (Constitution)          (does, impose)
# 481585                (’s, policy)                 (fails)
# 481586                      (1182)               (permits)
# 481588                   (Section)              (violated)
# 481590           (Court, majority)       (will, determine)
# 481591                      (seat)       (will, determine)
# 481592                   (Clinton)        (would, appoint)
# 481593                   (Clinton)    (would, never, make)
# 481594                    (person)           (could, side)
# 481595                  (justices)            (to, strike)
# 481596                     (Trump)            (to, create)
# 481601                       (all)              (approved)
# 481602                       (who)                  (feed)
# 481603                       (You)        (have, betrayed)
# 481606               (governments)                (follow)
# 481607                (commission)                (follow)
# 481609            (EU, Parliament)       (was, discussing)
# 481611                        (he)              (employed)
# 481613                    (Turkey)                  (made)
#
#                             object   start     end subj_dep subj_tag obj_dep  \
# 481541      (branches, discretion)   303.0   328.0    nsubj       NN    dobj
# 481542                   (country)   303.0   333.0    nsubj       WP    dobj
# 481544                      (case)   413.0   419.0    nsubj      NNP    dobj
# 481545                     (power)   413.0   434.0    nsubj      NNP    dobj
# 481546                       (ban)   445.0   455.0    nsubj      NNP    dobj
# 481550                 (authority)   565.0   571.0    nsubj       NN    dobj
# 481551         (policy, advocates)   565.0   580.0    nsubj       NN    dobj
# 481552                     (power)   597.0   606.0    nsubj       NN    dobj
# 481553                       (law)   597.0   620.0    nsubj      NNP    dobj
# 481554                  (religion)   725.0   741.0    nsubj      NNS    dobj
# 481555                    (Clause)   752.0   764.0    nsubj       WP    dobj
# 481556                 (Pickering)   776.0   781.0    nsubj      NNS    dobj
# 481558                       (law)   813.0   864.0    nsubj      PRP    dobj
# 481559                  (religion)   873.0   895.0    nsubj       NN    dobj
# 481560                    (asylum)   899.0   903.0    nsubj      NNS    dobj
# 481562              (truthfulness)   919.0   927.0    nsubj       NN    dobj
# 481564                  (religion)   939.0   958.0    nsubj      NNS    dobj
# 481565  (immigration, authorities)   977.0   984.0    nsubj       NN    dobj
# 481567                    (person)  1099.0  1118.0    nsubj       NN    dobj
# 481568                 (guarantee)  1151.0  1211.0    nsubj      NNP    dobj
# 481571                       (Ban)  1331.0  1336.0    nsubj      NNS    dobj
# 481572         (policy, judgments)  1353.0  1370.0    nsubj      NNP    dobj
# 481573                    (States)  1376.0  1392.0    nsubj       WP    dobj
# 481574                    (anyone)  1394.0  1401.0    nsubj      NNS    dobj
# 481575                     (claim)  1416.0  1435.0    nsubj       NN    dobj
# 481576                   (profile)  1458.0  1471.0    nsubj       WP    dobj
# 481577                   (victory)  1527.0  1534.0    nsubj       NN    dobj
# 481578                  (scrutiny)  1538.0  1555.0    nsubj       NN    dobj
# 481579                     (scope)  1581.0  1599.0    nsubj       NN    dobj
# 481580                     (scope)  1581.0  1599.0    nsubj       NN    dobj
# 481581                     (means)  1670.0  1720.0    nsubj      NNP    dobj
# 481582                    (limits)  1727.0  1735.0    nsubj      NNP    dobj
# 481585                      (test)  1761.0  1777.0    nsubj       NN    dobj
# 481586                 (president)  1779.0  1802.0    nsubj       CD    dobj
# 481588                 (Amendment)  1779.0  1826.0    nsubj       NN    dobj
# 481590                      (fate)  1837.0  1876.0    nsubj       NN    dobj
# 481591                      (fate)  1837.0  1876.0    nsubj       NN    dobj
# 481592                   (liberal)  1882.0  1886.0    nsubj      NNP    dobj
# 481593                    (policy)  1882.0  1914.0    nsubj      NNP    dobj
# 481594       (immigration, policy)  1986.0  2014.0    nsubj       NN    dobj
# 481595                     (parts)  1986.0  2008.0    nsubj      NNS    dobj
# 481596                    (policy)  2016.0  2037.0    nsubj       JJ    dobj
# 481601                      (vote)    74.0    88.0    nsubj       DT    dobj
# 481602                  (refugees)    92.0   102.0    nsubj       WP    dobj
# 481603                  (promises)   116.0   121.0    nsubj      PRP    dobj
# 481606                (parliament)   280.0   288.0    nsubj      NNS    dobj
# 481607                (parliament)   280.0   288.0     conj       NN    dobj
# 481609                    (motion)   306.0   316.0    nsubj      NNP    dobj
# 481611                  (rhetoric)   352.0   380.0    nsubj      PRP    dobj
# 481613                   (demands)   432.0   441.0    nsubj      NNP    dobj
#
#        obj_tag  Document publication
# 481541      NN     23779   Breitbart
# 481542      NN     23779   Breitbart
# 481544      NN     23779   Breitbart
# 481545      NN     23779   Breitbart
# 481546      NN     23779   Breitbart
# 481550      NN     23779   Breitbart
# 481551     NNS     23779   Breitbart
# 481552      NN     23779   Breitbart
# 481553      NN     23779   Breitbart
# 481554      NN     23779   Breitbart
# 481555     NNP     23779   Breitbart
# 481556     NNP     23779   Breitbart
# 481558      NN     23779   Breitbart
# 481559      NN     23779   Breitbart
# 481560      NN     23779   Breitbart
# 481562      NN     23779   Breitbart
# 481564      NN     23779   Breitbart
# 481565     NNS     23779   Breitbart
# 481567      NN     23779   Breitbart
# 481568      NN     23779   Breitbart
# 481571     NNP     23779   Breitbart
# 481572     NNS     23779   Breitbart
# 481573     NNP     23779   Breitbart
# 481574      NN     23779   Breitbart
# 481575      NN     23779   Breitbart
# 481576      NN     23779   Breitbart
# 481577      NN     23779   Breitbart
# 481578      NN     23779   Breitbart
# 481579      NN     23779   Breitbart
# 481580      NN     23779   Breitbart
# 481581     NNS     23779   Breitbart
# 481582     NNS     23779   Breitbart
# 481585      NN     23779   Breitbart
# 481586      NN     23779   Breitbart
# 481588     NNP     23779   Breitbart
# 481590      NN     23779   Breitbart
# 481591      NN     23779   Breitbart
# 481592      NN     23779   Breitbart
# 481593      NN     23779   Breitbart
# 481594      NN     23779   Breitbart
# 481595     NNS     23779   Breitbart
# 481596      NN     23779   Breitbart
# 481601      NN     23780   Breitbart
# 481602     NNS     23780   Breitbart
# 481603     NNS     23780   Breitbart
# 481606      NN     23780   Breitbart
# 481607      NN     23780   Breitbart
# 481609      NN     23780   Breitbart
# 481611      NN     23780   Breitbart
# 481613     NNS     23780   Breitbart

# %%
svodf_final.to_csv('~/Documents/moral_templates/Data/bb_triplets_dataset.csv')
